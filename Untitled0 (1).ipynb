# %%
import tensorflow as tf #models
import pandas as pd  #procesing and reading data
import seaborn as sns   #visualization
from tensorflow.keras.layers import Normalization,Dense,InputLayer
from tensorflow.keras.losses import MeanSquaredError,Huber,MeanAbsoluteError
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from tensorflow.keras.metrics import RootMeanSquaredError
import numpy as np


data = pd.read_csv("/train.csv",sep=",")
tensor_data=tf.constant(data)
tensor_data=tf.cast(tensor_data,tf.float32)
print(tensor_data)
tensor_data=tf.random.shuffle(tensor_data)
print(tensor_data[:5])
# Out:
# tf.Tensor(
# [[1.000000e+00 5.356510e+05 7.981860e+05 ... 7.300000e+01 1.230000e+02
#   3.513180e+05]
#  [2.000000e+00 5.919110e+05 8.610560e+05 ... 7.400000e+01 9.500000e+01
#   2.850015e+05]
#  [3.000000e+00 6.869900e+05 7.707620e+05 ... 5.300000e+01 9.700000e+01
#   2.153860e+05]
#  ...
#  [9.980000e+02 6.463440e+05 8.427330e+05 ... 1.130000e+02 8.900000e+01
#   4.058710e+05]
#  [9.990000e+02 5.355590e+05 7.324390e+05 ... 1.120000e+02 1.280000e+02
#   7.439800e+04]
#  [1.000000e+03 5.901050e+05 7.797430e+05 ... 9.900000e+01 9.600000e+01
#   4.149385e+05]], shape=(1000, 12), dtype=float32)
# tf.Tensor(
# [[4.930000e+02 6.145030e+05 8.316160e+05 7.000000e+00 1.295070e+05
#   2.000000e+00 4.000000e+00 1.400000e+01 1.630000e+02 7.500000e+01
#   1.150000e+02 1.974305e+05]
#  [5.680000e+02 6.767270e+05 7.560740e+05 4.000000e+00 1.175110e+05
#   3.000000e+00 1.000000e+00 1.300000e+01 1.390000e+02 1.200000e+02
#   1.230000e+02 2.462420e+05]
# ...

# %%
normalizer=Normalization()
normalizer.adapt(X_Train)
normalizer(X)[:5]
# Out:
# <tf.Tensor: shape=(5, 8), dtype=float32, numpy=
# array([[-0.321588  , -1.648589  , -1.456883  , -1.6414433 ,  0.15295944,
#         -0.8099869 , -0.42919892, -1.4369719 ],
#        [ 0.84782255, -0.54325956, -0.01976037,  1.2194599 ,  1.0494239 ,
#         -0.39370847,  0.9862124 ,  1.1718235 ],
#        [ 0.84782255,  1.6512796 , -1.456883  , -0.92621744, -1.6399695 ,
#          0.9071615 ,  0.74217594, -0.01399254],
#        [ 0.84782255, -0.90356314, -1.456883  ,  0.50423414, -0.2952728 ,
#         -0.02946489, -1.0148864 , -0.48831898],
#        [ 1.4325278 ,  0.9603846 , -1.456883  , -0.92621744, -0.74350506,
#          0.49088308, -0.1363552 ,  1.0769583 ]], dtype=float32)>

# %%
model=tf.keras.Sequential([
    InputLayer(input_shape=(8,)),
    normalizer,
    Dense(128,activation="relu"),
    Dense(128,activation="relu"),
    Dense(128,activation="relu"),
    Dense(1),
])
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization_4 (Normalization)      │ (None, 8)                   │              17 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 128)                 │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 128)                 │          16,512 │
# ...

# %%
model.summary()

tf.keras.utils.plot_model(model,to_file="model.png",show_shapes=True)
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization_4 (Normalization)      │ (None, 8)                   │              17 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 128)                 │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_24 (Dense)                     │ (None, 128)                 │          16,512 │
# ...

# %%
model.compile(optimizer=Adam(learning_rate=0.1),
              loss=MeanAbsoluteError(),
              metrics=[RootMeanSquaredError()])

# %%
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)) #validation
val_dataset = val_dataset.shuffle(buffer_size=8, reshuffle_each_iteration=True).batch(8).prefetch(tf.data.AUTOTUNE) # Applying operations to val_dataset

# %%
model.compile(
    optimizer=Adam(learning_rate=0.1),
    loss=MeanAbsoluteError(),
    metrics=[RootMeanSquaredError()]  # Remove 'loss' from metrics
)

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=100,
    verbose=1
)
# Out:
# Epoch 1/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 193830.3594 - root_mean_squared_error: 232742.5000 - val_loss: 187273.1875 - val_root_mean_squared_error: 220258.9219
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 139619.1406 - root_mean_squared_error: 170710.4375 - val_loss: 178603.0938 - val_root_mean_squared_error: 212472.0156
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 128704.7656 - root_mean_squared_error: 160574.0000 - val_loss: 139345.2188 - val_root_mean_squared_error: 165435.2031
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 125287.9219 - root_mean_squared_error: 152077.0469 - val_loss: 157088.3438 - val_root_mean_squared_error: 187675.4219
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 121477.4219 - root_mean_squared_error: 149867.2656 - val_loss: 115441.3594 - val_root_mean_squared_error: 140459.3438
# Epoch 6/100
# ...

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(['train','val_loss'])
plt.show()

# %%
model.evaluate(X_test,y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 137760.3438 - root_mean_squared_error: 169812.5938
# [136370.5625, 167840.734375]

# %%
X_test.shape
# Out:
# TensorShape([100, 8])

# %%
model.predict(tf.expand_dims(X_test[0],axis=0))
# Out:
# WARNING:tensorflow:6 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x793c9f9c3640> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# array([[395996.94]], dtype=float32)

# %%
y_test[0]
# Out:
# <tf.Tensor: shape=(1,), dtype=float32, numpy=array([158511.], dtype=float32)>

# %%
ind=np.arange(100)
plt.figure(figsize=(40,20))
witdh=0.4
#Obtain model predictions and store in y_pred
y_pred = model.predict(X_test[:100]).flatten() # Assuming you want to plot the first 100 predictions
# Assign y_true to actual values
y_true = y_test[:100].numpy().flatten() # Assuming y_test is a TensorFlow tensor
# Use witdh instead of width, which is a typo
plt.bar(ind,y_pred,witdh,label="predicted car price ")
plt.bar(ind +witdh,y_true,witdh,label="actual car price")
plt.xlabel("actual vs predicted car price")
plt.ylabel("car prices")

plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
plt.plot(history.history["root_mean_squared_error"])
plt.title("Model Perfomance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(['train'])
plt.show()

# %%
TRAIN_RATIO=0.8
VAL_RATIO=0.1
TEST_RATIO=0.1
DATASET_SIZE=len(X)

# %%
X_Train=X[:int(DATASET_SIZE*TRAIN_RATIO)] #training
y_Train=y[:int(DATASET_SIZE*TRAIN_RATIO)]
print(X_Train.shape)
print(y_Train.shape)
# Out:
# (800, 8)
# (8, 1)

# %%
X_val=X[int(DATASET_SIZE*TRAIN_RATIO):int(DATASET_SIZE*(TRAIN_RATIO+VAL_RATIO))] #validation
y_val=y[int(DATASET_SIZE*TRAIN_RATIO):int(DATASET_SIZE*(TRAIN_RATIO+VAL_RATIO))]
print(X_val.shape)
print(y_val.shape)
# Out:
# (100, 8)
# (0, 1)

# %%
X_test=X[int(DATASET_SIZE*(TRAIN_RATIO+VAL_RATIO)):] #testing
y_test=y[int(DATASET_SIZE*(TRAIN_RATIO+VAL_RATIO)):]
print(X_test.shape)
print(y_test.shape)
# Out:
# (100, 8)
# (0, 1)

# %%
# Out:
# (800, 8)
# (8, 1)

# %%
TRAIN_RATIO = 0.8
VAL_RATIO = 0.1  # Reduced to 0.1
TEST_RATIO = 0.1
DATASET_SIZE = len(X)

X_Train = X[:int(DATASET_SIZE * TRAIN_RATIO)]  # training
y_Train = y[:int(DATASET_SIZE * TRAIN_RATIO)]
print(X_Train.shape)
print(y_Train.shape)

X_val = X[int(DATASET_SIZE * TRAIN_RATIO):int(DATASET_SIZE * (TRAIN_RATIO + VAL_RATIO))]  # validation
y_val = y[int(DATASET_SIZE * TRAIN_RATIO):int(DATASET_SIZE * (TRAIN_RATIO + VAL_RATIO))]
print(X_val.shape)
print(y_val.shape)

X_test = X[int(DATASET_SIZE * (TRAIN_RATIO + VAL_RATIO)):]  # testing
y_test = y[int(DATASET_SIZE * (TRAIN_RATIO + VAL_RATIO)):]
print(X_test.shape)
print(y_test.shape)

train_dataset = tf.data.Dataset.from_tensor_slices((X_Train, y_Train))
train_dataset = train_dataset.shuffle(buffer_size=8, reshuffle_each_iteration=True).batch(8).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))  # validation
val_dataset = val_dataset.shuffle(buffer_size=8, reshuffle_each_iteration=True).batch(8).prefetch(tf.data.AUTOTUNE) # Applying operations to val_dataset
# Out:
# (800, 8)
# (8, 1)
# (100, 8)
# (0, 1)
# (100, 8)
# (0, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-149-15b826876482> in <cell line: 21>()
#      19 print(y_test.shape)
#      20
# ---> 21 train_dataset = tf.data.Dataset.from_tensor_slices((X_Train, y_Train))
#      22 train_dataset = train_dataset.shuffle(buffer_size=8, reshuffle_each_iteration=True).batch(8).prefetch(tf.data.AUTOTUNE)
#      23
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/dataset_ops.py in from_tensor_slices(tensors, name)
#     824     # pylint: disable=g-import-not-at-top,protected-access
#     825     from tensorflow.python.data.ops import from_tensor_slices_op
# --> 826     return from_tensor_slices_op._from_tensor_slices(tensors, name)
#     827     # pylint: enable=g-import-not-at-top,protected-access
#     828
#
# ...

# %%
TRAIN_RATIO = 0.8
VAL_RATIO = 0.1  # Reduced to 0.1
TEST_RATIO = 0.1
DATASET_SIZE = len(X)

X_Train = X[:int(DATASET_SIZE * TRAIN_RATIO)]  # training
y_Train = y[:int(DATASET_SIZE * TRAIN_RATIO)]
print(X_Train.shape)
print(y_Train.shape)

X_val = X[int(DATASET_SIZE * TRAIN_RATIO):int(DATASET_SIZE * (TRAIN_RATIO + VAL_RATIO))]  # validation
y_val = y[int(DATASET_SIZE * TRAIN_RATIO):int(DATASET_SIZE * (TRAIN_RATIO + VAL_RATIO))]
print(X_val.shape)
print(y_val.shape)

X_test = X[int(DATASET_SIZE * (TRAIN_RATIO + VAL_RATIO)):]  # testing
y_test = y[int(DATASET_SIZE * (TRAIN_RATIO + VAL_RATIO)):]
print(X_test.shape)
print(y_test.shape)

# The issue was that y was being overwritten in a previous code block.
# It's now being sliced correctly to match the X splits.

train_dataset = tf.data.Dataset.from_tensor_slices((X_Train, y_Train))
train_dataset = train_dataset.shuffle(buffer_size=8, reshuffle_each_iteration=True).batch(8).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))  # validation
val_dataset = val_dataset.shuffle(buffer_size=8, reshuffle_each_iteration=True).batch(8).prefetch(tf.data.AUTOTUNE) # Applying operations to val_dataset
# Out:
# (800, 8)
# (8, 1)
# (100, 8)
# (0, 1)
# (100, 8)
# (0, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-c7e870dce7cc> in <cell line: 24>()
#      22 # It's now being sliced correctly to match the X splits.
#      23
# ---> 24 train_dataset = tf.data.Dataset.from_tensor_slices((X_Train, y_Train))
#      25 train_dataset = train_dataset.shuffle(buffer_size=8, reshuffle_each_iteration=True).batch(8).prefetch(tf.data.AUTOTUNE)
#      26
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/dataset_ops.py in from_tensor_slices(tensors, name)
#     824     # pylint: disable=g-import-not-at-top,protected-access
#     825     from tensorflow.python.data.ops import from_tensor_slices_op
# --> 826     return from_tensor_slices_op._from_tensor_slices(tensors, name)
#     827     # pylint: enable=g-import-not-at-top,protected-access
#     828
#
# ...

# %%
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)) #test
test_dataset = train_dataset.shuffle(buffer_size=8, reshuffle_each_iteration=True).batch(8).prefetch(tf.data.AUTOTUNE)

# %%
for x,y in train_dataset:
  print(x,y)
  break

# %%
#data preparation
X=tensor_data[:,3:-1]
print(X[:5])

# %%
y=tensor_data[:,-1]
print(y[:5].shape)
y=tf.expand_dims(y,axis=-1)
print(y[:5])
